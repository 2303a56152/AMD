# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a56152/AMD/blob/main/Assienment_02_1652.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
data = pd.DataFrame({'Age': np.random.randint(20, 70, size=100)})

# %%
plt.hist(data['Age'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Basic Histograms')
# Out:
# Text(0.5, 1.0, 'Basic Histograms')
